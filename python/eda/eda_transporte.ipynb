# %%
import pandas as pd

df = pd.read_csv("../../data/raw/transporte_publico_quito.csv")
print(df.shape)
df.head()
# Out:
# (175205, 13)
#             fecha_hora  mes  hora  dia_semana  es_fin_semana  \
# 0  2024-01-01 00:00:00    1     0           0          False
# 1  2024-01-01 00:00:00    1     0           0          False
# 2  2024-01-01 00:00:00    1     0           0          False
# 3  2024-01-01 00:00:00    1     0           0          False
# 4  2024-01-01 00:00:00    1     0           0          False
#
#                                             ruta      clima  \
# 0                  Trolebús: Quitumbe - Labrador  Despejado
# 1                    Ecovía: Río Coca - Quitumbe  Despejado
# 2  Corredor Sur Occidental: Quitumbe - La Ofelia  Despejado
# 3   Bus Convencional: Cumbayá - Centro Histórico  Despejado
# 4   Bus Convencional: Carcelén - Seminario Mayor  Despejado
#
#    frecuencia_min_programada  num_unidades_activas  \
# 0                         60                     1
# 1                         60                     1
# 2                         60                     1
# ...

# %%
print("Nulos por columna:")
print(df.isnull().sum())
print("\nFilas duplicadas:", df.duplicated().sum())
# Out:
# Nulos por columna:
# fecha_hora                     0
# mes                            0
# hora                           0
# dia_semana                     0
# es_fin_semana                  0
# ruta                           0
# clima                          0
# frecuencia_min_programada      0
# num_unidades_activas           0
# pasajeros_totales_estimados    0
# tiempo_viaje_promedio_min      0
# estado_operacional             0
# ocupacion_porcentaje           0
# dtype: int64
#
# Filas duplicadas: 0

# %%
df_limpio = df.drop_duplicates()
df_limpio.shape
# Out:
# (175205, 13)

# %%
df_limpio.to_csv("../../data/processed/transporte_publico_limpio.csv", index=False)
print("Guardado en data/processed/")
# Out:
# Guardado en data/processed/
