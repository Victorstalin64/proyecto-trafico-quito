# %%
import pandas as pd

df = pd.read_csv("../../data/raw/eventos_quito_simulado.csv")
print(df.shape)
df.head()
# Out:
# (700820, 8)
#             fecha_hora  hora  dia_semana         zona tipo_evento  \
# 0  2024-01-01 00:00:00     0           0  La Carolina     Ninguno
# 1  2024-01-01 00:00:00     0           0     El Ejido       Feria
# 2  2024-01-01 00:00:00     0           0  La Mariscal     Ninguno
# 3  2024-01-01 00:00:00     0           0  La Floresta     Ninguno
# 4  2024-01-01 00:00:00     0           0     El Batán     Ninguno
#
#    evento_activo  asistentes_estimados  impacto_trafico_pct
# 0          False                     0                  0.0
# 1           True                 11033                 28.0
# 2          False                     0                  0.0
# 3          False                     0                  0.0
# 4          False                     0                  0.0

# %%
print("Nulos por columna:")
print(df.isnull().sum())
print("\nFilas duplicadas:", df.duplicated().sum())
# Out:
# Nulos por columna:
# fecha_hora              0
# hora                    0
# dia_semana              0
# zona                    0
# tipo_evento             0
# evento_activo           0
# asistentes_estimados    0
# impacto_trafico_pct     0
# dtype: int64
#
# Filas duplicadas: 0

# %%
df_limpio = df.drop_duplicates()
df_limpio.shape
# Out:
# (700820, 8)

# %%
df_limpio.to_csv("../../data/processed/eventos_limpio.csv", index=False)
print("Guardado en data/processed/")
# Out:
# Guardado en data/processed/
